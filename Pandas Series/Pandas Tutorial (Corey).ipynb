# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
#info methods gives us the number of rows and column in  a turple and also the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
# shape attribute gives us the number of rows and column in  a turple 
df.shape
# Out:
# (88883, 85)

# %%
# to check all the columns we change the following setting 
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %% [markdown]
# ## DataFrame and Series Basics: Selecting Rows and Columns

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
# ccessing rows 

# iloc alliows to access the rows using the index location 
# loc searching by lable(indexes)
df.iloc[[0,1],3]
# Out:
# 0                      Never
# 1    Less than once per year
# Name: OpenSourcer, dtype: object

# %%
# df.iloc[0]

# %%
df.iloc[[0,1]]
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
# usinfg the loc function 
df.loc[[0,1],['Respondent', 'Hobbyist']]
# Out:
#    Respondent Hobbyist
# 0           1      Yes
# 1           2       No

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
# Grabbing the hobbyist column 
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
# grabbing specific rows and specific columns 
df.loc[0, 'Hobbyist']
df.loc[[0,1,2], 'Hobbyist']

# slicing rows 
df.loc[0:20, 'Hobbyist']

#sclicing rows
df.loc[0:20, 'Hobbyist':'Employment']
# Out:
#    Hobbyist                                        OpenSourcer  \
# 0       Yes                                              Never
# 1        No                            Less than once per year
# 2       Yes                                              Never
# 3        No                                              Never
# 4       Yes                         Once a month or more often
# 5       Yes                                              Never
# 6        No                                              Never
# 7       Yes                            Less than once per year
# 8       Yes                         Once a month or more often
# 9       Yes                         Once a month or more often
# 10      Yes                         Once a month or more often
# 11       No                                              Never
# 12      Yes  Less than once a month but more than once per ...
# 13      Yes                            Less than once per year
# ...

# %% [markdown]
# ## Indexes: How to Set, Rest, and Use Indexes

# %%
# the index_col set the column in question as the index column 
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
# now we can search for the columns directly using the loc functions 
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrMoney']
# Out:
# QuestionText    Do you believe that you need to be a manager t...
# Name: MgrMoney, dtype: object

# %%
# seeing the full text, access both teh rows and columns 
schema_df.loc['MgrMoney', 'QuestionText']
# Out:
# 'Do you believe that you need to be a manager to make more money?'

# %%
# sorting the indexes alphabetically
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# # Filtering
# ## Using Conditionals to Filter Rows and Columns

# %%
ConvertedComp = [df['ConvertedComp'] >70000]

# %%
high_salary = (df['ConvertedComp'] >70000)

# %%
df.loc[high_salary]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 8               9                     I am a developer by profession      Yes
# 12             13                     I am a developer by profession      Yes
# 15             16                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88323       88876                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
# 88326       88879                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
#
# ...

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# 0        United Kingdom
# 3         United States
# 5                Canada
# 7                 India
# 9                 India
#               ...
# 88859     United States
# 88863    United Kingdom
# 88864             India
# 88877     United States
# 88878            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
filt
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 1               2  I am a student who is learning to code       No
# 3               4          I am a developer by profession       No
# 4               5          I am a developer by profession      Yes
# 7               8             I code primarily as a hobby      Yes
# ...           ...                                     ...      ...
# 88854       84539                                     NaN      Yes
# 88860       85738                                     NaN      Yes
# 88865       86566                                     NaN      Yes
# 88872       87739                                     NaN      Yes
# 88876       88212                                     NaN       No
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %% [markdown]
# ## Updating Rows and Columns - Modifying Data within DataFrames

# %%
# df.columns

# %%
# df.columns = [x.upper() for x in df.columns]
# df.columns = df.columns.str.replace(' ', '_')

## renaming specific columns 
# df.rename(columns = {'value': 'New value', 'value2':'New value2'}, inplace=True)
# df

# %%
# #updating Data in row 
# df.loc[index] = ['value', 'value', 'value']

# #updating specific coumns 
# df.loc[index, ['column1', 'column2', 'column3']] = ['value1', 'value2', 'value3']

# %%
# #usinf the .at instead of loc of a single row of data
# df.at[2, 'value'] = 'value'
# filt= (df['value']== 'value')
# df[filt]
# or
# df[filt]['value']

# #setting new value to a column 
# filt= (df['value']== 'value')
# df.loc[filt, 'column_value'] = 'newvalue'

# #changing multiple values of a row
# df['value'] = df['value'].str.lower()

# four methods: apply, map, applymap, replace

# 1. apply: used for calling a function on a values.can work for either a dataframe or a series
# grabbing some information about data on a series
# df['value'].apply(len)
# df['value'].apply(lambda x: x.lower)

# applymap only works on a data frame 
# df.applymap(len)
# df.applymap(str.lower)

# df['value'].map{'value': 'rvalue', 'value2':'rvalue2'})
# df['value']= df['value'].replace({'value': 'rvalue', 'value2':'rvalue2'})

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace= True)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist']=df['Hobbyist'].map({'Yes':True, 'No': False})

# %%
df
# Out:
#        Respondent                                         MainBranch  \
# 0               1             I am a student who is learning to code
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 88878       88377                                                NaN
# 88879       88601                                                NaN
# 88880       88802                                                NaN
# 88881       88816                                                NaN
# 88882       88863                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 0          True                                              Never
# ...

# %%
df['OpenSourcer'] = df['OpenSourcer'].replace({'Never': 'Beginner'})

# %%
df
# Out:
#        Respondent                                         MainBranch  \
# 0               1             I am a student who is learning to code
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 88878       88377                                                NaN
# 88879       88601                                                NaN
# 88880       88802                                                NaN
# 88881       88816                                                NaN
# 88882       88863                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 0          True                                           Beginner
# ...

# %% [markdown]
# ## Add/Remove Rows and Columns from a DataFrame

# %%
# #ading column: combininng fname and lname
# df['Full_name'] = df['fname']+ ' '+ df['lname']

# #Removing/dropping columns 
# df.rop(columns=['fname', 'lname'], inplace=True)

# #reversing the changes 
# df['Full_name'].str.split(' ', expand=True)
# df[['fisrt', 'last']] = df['Full_name'].str.split(' ', expand=True)

# #Adding and removing rows 
# #ading a single row
# df.append ({'first': 'Tonny'}, ignore_index=True)

# #adding multiple rows 
# df.append(df2, ignore_index=True)
# df = df.append(df2, ignore_index=True)

# #removing rows 
# df.drop(index=4, inplace=True)
# df.drop(index=df[filt =df['last']=='doe'].index)
# # or
# filt =df['last']=='doe'
# df.drop(index=df[filt].index)

# %%
# # Sorting Data 

# df.sort_values(by='last')
# df.sort_values(by=['last', 'first'], ascending=False)
# df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=true)
# df.sort_index()
# df['last'].sort_values()

# %%
df.head()
# Out:
#    Respondent                                         MainBranch  Hobbyist  \
# 0           1             I am a student who is learning to code      True
# 1           2             I am a student who is learning to code     False
# 2           3  I am not primarily a developer, but I write co...      True
# 3           4                     I am a developer by profession     False
# 4           5                     I am a developer by profession      True
#
#                   OpenSourcer  \
# 0                    Beginner
# 1     Less than once per year
# 2                    Beginner
# 3                    Beginner
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# sorting by country name 
df.sort_values(by='Country', inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(60)
# Out:
#            Country  SalaryUSD
# 39018  Afghanistan    19152.0
# 62723  Afghanistan  1000000.0
# 85185  Afghanistan        NaN
# 50437  Afghanistan        NaN
# 88340  Afghanistan        NaN
# 88735  Afghanistan        NaN
# 6391   Afghanistan        NaN
# 39754  Afghanistan        NaN
# 88181  Afghanistan        NaN
# 48122  Afghanistan     4464.0
# 10697  Afghanistan     3996.0
# 62124  Afghanistan        NaN
# 49377  Afghanistan        NaN
# 32971  Afghanistan        NaN
# 60559  Afghanistan        NaN
# 85827  Afghanistan        NaN
# 88033  Afghanistan        NaN
# 28470  Afghanistan        0.0
# 719    Afghanistan        0.0
# 26189  Afghanistan        NaN
# 86394  Afghanistan        NaN
# 85293  Afghanistan        NaN
# 7056   Afghanistan    14364.0
# 7323   Afghanistan        NaN
# 86551  Afghanistan        NaN
# 58390  Afghanistan        NaN
# 73920  Afghanistan        NaN
# 28877  Afghanistan        NaN
# 51525  Afghanistan        NaN
# 45562  Afghanistan        NaN
# ...

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending =[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(60)
# Out:
#            Country  SalaryUSD
# 62723  Afghanistan  1000000.0
# 50172  Afghanistan   153216.0
# 39018  Afghanistan    19152.0
# 58082  Afghanistan    17556.0
# 7056   Afghanistan    14364.0
# 22327  Afghanistan     7980.0
# 48122  Afghanistan     4464.0
# 10697  Afghanistan     3996.0
# 8112   Afghanistan     1596.0
# 29560  Afghanistan     1116.0
# 28470  Afghanistan        0.0
# 719    Afghanistan        0.0
# 85185  Afghanistan        NaN
# 50437  Afghanistan        NaN
# 88340  Afghanistan        NaN
# 88735  Afghanistan        NaN
# 6391   Afghanistan        NaN
# 39754  Afghanistan        NaN
# 88181  Afghanistan        NaN
# 62124  Afghanistan        NaN
# 49377  Afghanistan        NaN
# 32971  Afghanistan        NaN
# 60559  Afghanistan        NaN
# 85827  Afghanistan        NaN
# 88033  Afghanistan        NaN
# 26189  Afghanistan        NaN
# 86394  Afghanistan        NaN
# 85293  Afghanistan        NaN
# 7323   Afghanistan        NaN
# 86551  Afghanistan        NaN
# ...

# %%
# grabbing the 10 largest salary 
df['SalaryUSD'].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#        Respondent                                         MainBranch  \
# 25833       25983                     I am a developer by profession
# 87353       87896                     I am a developer by profession
# 21895       22013                     I am a developer by profession
# 28080       28243                     I am a developer by profession
# 72274       72732  I am not primarily a developer, but I write co...
# 77665       78151                     I am a developer by profession
# 79701       80200                     I am a developer by profession
# 51798       52132                     I am a developer by profession
# 75088       75561                     I am a developer by profession
# 32056       32250                     I am a developer by profession
#
#        Hobbyist                                        OpenSourcer  \
# 25833      True                            Less than once per year
# 87353      True                            Less than once per year
# ...

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#        Respondent                                         MainBranch  \
# 28470       28638                     I am a developer by profession
# 719           722                     I am a developer by profession
# 13760       13825                     I am a developer by profession
# 40655       40913                     I am a developer by profession
# 30447       30630                     I am a developer by profession
# 68611       69049                     I am a developer by profession
# 19235       19340  I am not primarily a developer, but I write co...
# 16126       16214  I am not primarily a developer, but I write co...
# 29184       29355                     I am a developer by profession
# 1678         1685                     I am a developer by profession
#
#        Hobbyist                                        OpenSourcer  \
# 28470      True  Less than once a month but more than once per ...
# 719       False  Less than once a month but more than once per ...
# ...

# %% [markdown]
# ## Grouping and Aggregating - Analzing and Exploring Data

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df[['CompTotal', 'SalaryUSD', 'WorkWeekHrs', 'CodeRevHrs', 'Age']].median()
# Out:
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11  1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
# counts the value without NaN
df['SalaryUSD'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# True     71257
# False    17626
# Name: count, dtype: int64

# %%
df['SocialMedia']
# Out:
# 62723    I don't use social media
# 50172                    WhatsApp
# 39018                    Facebook
# 58082                    Facebook
# 7056                    Instagram
#                    ...
# 88873                         NaN
# 88874                         NaN
# 88879                         NaN
# 88880                         NaN
# 88881                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
# checking the most popular social media based on the country
# Spil applying a function and then combining those results

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %%
df.groupby(['Country'])

# %%
cntry_grp = df.groupby(['Country'])

# %%
cntry_grp.get_group('United States')
# Out:
# /tmp/ipykernel_47016/261729356.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   cntry_grp.get_group('United States')
#        Respondent                      MainBranch  Hobbyist  \
# 2927         2940  I am a developer by profession      True
# 3119         3133  I am a developer by profession      True
# 78468       78960  I am a developer by profession      True
# 3106         3120  I am a developer by profession      True
# 78362       78853  I am a developer by profession     False
# ...           ...                             ...       ...
# 32602       32801  I am a developer by profession     False
# 32612       32811  I am a developer by profession     False
# 32686       32886  I am a developer by profession     False
# 68166       68604  I am a developer by profession      True
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#        Respondent                      MainBranch  Hobbyist  \
# 2927         2940  I am a developer by profession      True
# 3119         3133  I am a developer by profession      True
# 78468       78960  I am a developer by profession      True
# 3106         3120  I am a developer by profession      True
# 78362       78853  I am a developer by profession     False
# ...           ...                             ...       ...
# 32602       32801  I am a developer by profession     False
# 32612       32811  I am a developer by profession     False
# 32686       32886  I am a developer by profession     False
# 68166       68604  I am a developer by profession      True
# 33583       33792  I am a developer by profession      True
#
#                                              OpenSourcer  \
# 2927                                            Beginner
# 3119                                            Beginner
# 78468                            Less than once per year
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: count, dtype: int64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
cntry_grp['SocialMedia'].value_counts().head(60)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
cntry_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
cntry_grp['SocialMedia'].value_counts(normalize=True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: proportion, dtype: float64

# %%
# checking mean, median, count, of countries using the cntry_grp
# cntry_grp['SalaryUSD'].median().head(60)
cntry_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: SalaryUSD, Length: 179, dtype: float64

# %%
cntry_grp['SalaryUSD'].median().loc['Kenya']
# Out:
# 11940.0

# %%
cntry_grp['SalaryUSD'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
cntry_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith']
# Out:
# 21895    Assembly;Bash/Shell/PowerShell;C;C++;Java;Java...
# 28080            C++;C#;Java;JavaScript;Objective-C;Python
# 72274                                      Java;Python;SQL
# 80420    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Object...
# 77778    Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
#                                ...
# 78820    C;C++;Go;HTML/CSS;Java;JavaScript;Objective-C;...
# 79134                                           JavaScript
# 88577                                  Assembly;TypeScript
# 75925                       Bash/Shell/PowerShell;Java;SQL
# 30271                   C;C++;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# 21895     True
# 28080     True
# 72274     True
# 80420    False
# 77778     True
#          ...
# 78820     True
# 79134    False
# 88577    False
# 75925    False
# 30271    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
# cntry_grp['LanguageWorkedWith'].str.contains('Python').sum()

# %%
cntry_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %%
country_uses_python = cntry_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                   count  LanguageWorkedWith
# Country
# United States                     20949               10083
# India                              9061                3105
# Germany                            5866                2451
# United Kingdom                     5737                2384
# Canada                             3395                1558
# ...                                 ...                 ...
# North Korea                           1                   0
# Niger                                 1                   1
# Saint Vincent and the Grenadines      1                   0
# Chad                                  1                   0
# Brunei Darussalam                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'count': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowPython'}, inplace=True)
python_df
# Out:
#                                   NumRespondents  NumKnowPython
# Country
# United States                              20949          10083
# India                                       9061           3105
# Germany                                     5866           2451
# United Kingdom                              5737           2384
# Canada                                      3395           1558
# ...                                          ...            ...
# North Korea                                    1              0
# Niger                                          1              1
# Saint Vincent and the Grenadines               1              0
# Chad                                           1              0
# Brunei Darussalam                              1              0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowPython'] = (python_df['NumKnowPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                   NumRespondents  NumKnowPython  PctKnowPython
# Country
# United States                              20949          10083      48.131176
# India                                       9061           3105      34.267741
# Germany                                     5866           2451      41.783157
# United Kingdom                              5737           2384      41.554820
# Canada                                      3395           1558      45.891016
# ...                                          ...            ...            ...
# North Korea                                    1              0       0.000000
# Niger                                          1              1     100.000000
# Saint Vincent and the Grenadines               1              0       0.000000
# Chad                                           1              0       0.000000
# Brunei Darussalam                              1              0       0.000000
#
# ...

# %%
python_df.sort_values(by='PctKnowPython', ascending=False)
# Out:
#                                   NumRespondents  NumKnowPython  PctKnowPython
# Country
# Sao Tome and Principe                          1              1     100.000000
# Niger                                          1              1     100.000000
# Dominica                                       1              1     100.000000
# Timor-Leste                                    1              1     100.000000
# Turkmenistan                                   7              6      85.714286
# ...                                          ...            ...            ...
# Burkina Faso                                   4              0       0.000000
# Lao People's Democratic Republic               3              0       0.000000
# Gabon                                          2              0       0.000000
# Cape Verde                                     3              0       0.000000
# Brunei Darussalam                              1              0       0.000000
#
# ...

# %%
python_df.sort_values(by='PctKnowPython', ascending=False, inplace=True)
python_df
# Out:
#                                   NumRespondents  NumKnowPython  PctKnowPython
# Country
# Sao Tome and Principe                          1              1     100.000000
# Niger                                          1              1     100.000000
# Dominica                                       1              1     100.000000
# Timor-Leste                                    1              1     100.000000
# Turkmenistan                                   7              6      85.714286
# ...                                          ...            ...            ...
# Burkina Faso                                   4              0       0.000000
# Lao People's Democratic Republic               3              0       0.000000
# Gabon                                          2              0       0.000000
# Cape Verde                                     3              0       0.000000
# Brunei Darussalam                              1              0       0.000000
#
# ...

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowPython  PctKnowPython
# Country
# Sao Tome and Principe                          1              1     100.000000
# Niger                                          1              1     100.000000
# Dominica                                       1              1     100.000000
# Timor-Leste                                    1              1     100.000000
# Turkmenistan                                   7              6      85.714286
# Mauritania                                     7              5      71.428571
# Guinea                                         3              2      66.666667
# Bahamas                                        3              2      66.666667
# Guyana                                         3              2      66.666667
# Uganda                                        72             47      65.277778
# Iceland                                       49             30      61.224490
# ...

# %%
python_df.loc['Uganda']
# Out:
# NumRespondents    72.000000
# NumKnowPython     47.000000
# PctKnowPython     65.277778
# Name: Uganda, dtype: float64

# %% [markdown]
# ## Cleaning Data- Casting DataTypes and Handling Missing Values

# %%
# # droping rows with missing value
# df.dropna()
# df.dropna(axis='index', how='any') #works the same as dropna. it drops rows that have any missing value

# df.dropna(axis='index', how='all') # drop only rows with all columns as NaN

#df.dropna(axis='column', how='any')

# df.dropna(axis='index', how='any', subset=['email']) # drops rows without emial vaule

#df.dropna(axis='index', how='all', subset=['last', 'email']). #keeps rows that either has last or email or both

# # droping custom missing values 
# # replace the custom missing value with numpy na
# df.repace('custom missing value', np.nan, inplace=True)

# # getting values that are classified as na
# df.isna() #true=na false=not na

# # if you want to fill certain na with other values 
# df.fillna('MISSING') 
# df.fillna(0, inplace=True)

# # Custing datatypes 
# df.dtypes
# df['age'] = df['age'].astype(int) #cannot convert the np.na
# df['age'] = df['age'].astype(float)

# %%
# na_vals = ['NA', 'MSSING']
# df = pd.read_csv('surveyresults.csv', index_col='respondent', na_values=na_vals)
# # the above code is used to hande custom missing value in a cvs file as na

# %%
df['YearsCode'].head(30)
# Out:
# 62723    Less than 1 year
# 50172                   7
# 39018                   2
# 58082                   6
# 7056                    7
# 22327                   3
# 48122                   2
# 10697                   4
# 8112                    2
# 29560                  10
# 28470                  36
# 719      Less than 1 year
# 85185                   8
# 50437                 NaN
# 88340                   3
# 88735                   2
# 6391                    1
# 39754                   3
# 88181    Less than 1 year
# 62124                   2
# 49377                 NaN
# 32971                  20
# 60559                   2
# 85827                   2
# 88033                  28
# 26189                   1
# 86394                   4
# 85293                   3
# 7323                  NaN
# 86551                  31
# Name: YearsCode, dtype: object

# %%
df
# Out:
#        Respondent                                         MainBranch  \
# 62723       63129                     I am a developer by profession
# 50172       50499  I am not primarily a developer, but I write co...
# 39018       39258                     I am a developer by profession
# 58082       58450                     I am a developer by profession
# 7056         7085                     I am a developer by profession
# ...           ...                                                ...
# 88873       88062                                                NaN
# 88874       88076                                                NaN
# 88879       88601                                                NaN
# 88880       88802                                                NaN
# 88881       88816                                                NaN
#
#        Hobbyist              OpenSourcer  \
# 62723      True                 Beginner
# 50172      True  Less than once per year
# ...

# %%
# df['YearsCode'].mean()

# %%
# viewing the unique values 
df['YearsCode'].unique()
# Out:
# array(['Less than 1 year', '7', '2', '6', '3', '4', '10', '36', '8', nan,
#        '1', '20', '28', '31', '9', '5', 'More than 50 years', '15', '13',
#        '12', '17', '18', '35', '14', '21', '25', '11', '19', '22', '23',
#        '40', '39', '30', '43', '27', '33', '29', '24', '34', '16', '26',
#        '32', '38', '44', '45', '41', '37', '47', '42', '46', '48', '49',
#        '50'], dtype=object)

# %%
df['YearsCode'].replace ('Less than 1 year',0, inplace=True)

# %%
df['YearsCode'].replace ('More than 50 years',51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([0, '7', '2', '6', '3', '4', '10', '36', '8', nan, '1', '20', '28',
#        '31', '9', '5', 51, '15', '13', '12', '17', '18', '35', '14', '21',
#        '25', '11', '19', '22', '23', '40', '39', '30', '43', '27', '33',
#        '29', '24', '34', '16', '26', '32', '38', '44', '45', '41', '37',
#        '47', '42', '46', '48', '49', '50'], dtype=object)

# %%
df['YearsCode']= df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# ## working with Dates and Time Series Data

# %%
df2 = pd.read_csv('ETH_1h.csv')
# loading data as daytime for certain column 
# d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
# df2 = pd.read_csv('ETH_1h.csv', parse_dates = ['Date'], date_parser=d_parser)

# %%
df2.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df2.shape
# Out:
# (23674, 7)

# %%
df2['Date'].dtype
# Out:
# dtype('O')

# %%
df2.loc[0, 'Date']
# Out:
# '2020-03-13 08-PM'

# %%
df2.loc[0, 'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 df2.loc[0, 'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df2['Date'] = pd.to_datetime(df2['Date'], format='%Y-%m-%d %I-%p')

# %%
df2['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df2.loc[23669, 'Date'].day_name()
# Out:
# 'Saturday'

# %%
df2['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df2['DayofWeek'] = df2['Date'].dt.day_name()

# %%
df2
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayofWeek
# ...

# %%
# viewing the earliest and latest date 
df2['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df2['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
# checking time span 
df2['Date'].max() - df2['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
# doing filters 
filt = (df2['Date'] >= '2020')
df2.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayofWeek
# 0        Friday
# ...

# %%
filt = (df2['Date'] >= '2019') & (df2['Date'] <'2020')
df2.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayofWeek
# ...

# %%
filt = (df2['Date'] >= pd.to_datetime('2019-01-01')) & (df2['Date'] <pd.to_datetime('2020-01-01'))
df2.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayofWeek
# ...

# %%
df2.set_index('Date',inplace=True)

# %%
df2
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayofWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
# df2['2020-01': '2020-02']

# %%
highs = df2['High'].resample('D').max()

# %%
highs
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df2.resample('W').agg({'Close': 'mean', 'High': 'max'})
# Out:
#                  Close    High
# Date
# 2017-07-02  268.202162  293.73
# 2017-07-09  261.062083  285.00
# 2017-07-16  195.698393  240.33
# 2017-07-23  212.783750  249.40
# 2017-07-30  203.309524  229.99
# ...                ...     ...
# 2020-02-16  255.198452  290.00
# 2020-02-23  265.321905  287.13
# 2020-03-01  236.373988  278.13
# 2020-03-08  229.817619  253.01
# 2020-03-15  176.332821  208.65
#
# [142 rows x 2 columns]

# %%
# df2.resample('W').mean()

# %% [markdown]
# # Reading/Writing Data to Different SOurces - Excel, JSON, SQL

# %%
# Writing CSV file
filt = (df['Country'] == 'India')
India_filt = df.loc[filt]

# %%
India_filt.head()
# Out:
#        Respondent                                         MainBranch  \
# 21895       22013                     I am a developer by profession
# 28080       28243                     I am a developer by profession
# 72274       72732  I am not primarily a developer, but I write co...
# 80420       80923                     I am a developer by profession
# 77778       78265                     I am a developer by profession
#
#        Hobbyist                                        OpenSourcer  \
# 21895      True                                           Beginner
# 28080      True                         Once a month or more often
# 72274     False  Less than once a month but more than once per ...
# 80420      True                         Once a month or more often
# 77778      True                         Once a month or more often
#
#                                               OpenSource  \
# 21895  The quality of OSS and closed source software ...
# ...

# %%
India_filt.to_csv('modified.csv')

# %%
# read and write to other file
India_filt.to_csv('modified.tsv', sep='\t')

# %%
# if you want to work with excel 
# install xlwt, openpyxl, xlrd

# writing 
# India_filt.to_excel('modified.xlsx')

# # Reading excel filel
# df = pd.read_excel('modified.xlsx')

# %%
# #wriitng to JSON 
# Indian_df.to_json('modified.json') # this is dictionary like

# Indian_df.to_json('modified.json', orient='records', lines=True) #reads data in line like


# reading data in json format
# df = pd.read_json('modified.json', orient='records', lines=True)

# %%
# # connecting to database 
# # install package first: SQLAlchemy

# connecting to the db 
# from SQLAlchemy import create_engine

# engine = create_engine
# df.to_sql('sampletabel', engine )

# reWriting data to teh data base 
# df.to_sql('sampletabel', engine , if_exists='replace')

# reading data 
# sql_df = pd.read_sql('sample_tabe', engine, index_col='value')

# %%
# loading data using URL
# post_df = pd.read_json('url')
