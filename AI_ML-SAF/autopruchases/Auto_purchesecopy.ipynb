# %% [markdown]
# HCIA class 1.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('auto_purchases.csv')

# %%
# type(df)
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.shape
# Out:
# (61, 10)

# %%
# checking the data types of the data frame columns 
df.dtypes
# Out:
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
# checking data type for a specific column
print (df['company'].dtype)
# Out:
# object

# %%
# selecting a column in a data frame
df['company']
# Out:
# 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
#          ...
# 56     volkswagen
# 57     volkswagen
# 58     volkswagen
# 59          volvo
# 60          volvo
# Name: company, Length: 61, dtype: object

# %%
# checking the description of a specific columns
df.company.describe()
# Out:
# count         61
# unique        16
# top       toyota
# freq           7
# Name: company, dtype: object

# %%
# Grouping data usign rank
df_rank = df.groupby(['company'])
# df_rank.mean()
df_rank

# %%
# claculating mean salary for each of company rank
df.groupby('company')[['price']].mean()
# df.groupby('company')['price'].mean()
# Out:
#                       price
# company
# alfa-romero    15498.333333
# audi           16392.500000
# bmw            27213.333333
# chevrolet       6007.000000
# dodge           6303.000000
# honda          10195.000000
# isuzu           6785.000000
# jaguar         34600.000000
# mazda           9654.800000
# mercedes-benz  35040.000000
# mitsubishi      6689.000000
# nissan          8289.000000
# porsche        35528.000000
# toyota          8216.857143
# volkswagen      8435.000000
# volvo          13177.500000

# %%
# Calculating the mean price for each company rank:

df_sub = df[df['price']>15000]
df_sub.sort_values (by='price', ascending=True )
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 5       5           audi        sedan        99.8   177.3         ohc
# 54     79         toyota        wagon       104.5   187.8        dohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 8      10            bmw        sedan       101.2   176.8         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 31     43          mazda        sedan       104.9   175.0         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 32     44  mercedes-benz        sedan       110.0   190.9         ohc
# 33     45  mercedes-benz        wagon       110.0   190.9         ohc
# ...

# %%
# selecting only only raws that contains audi company
df_audi = df[df['company']=='audi']
df_audi

# sorting the selcted raws in ascending order 

df_audi.sort_values(by='price', ascending=True)
# Out:
#    index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 3      3    audi      sedan        99.8   176.6         ohc             four
# 5      5    audi      sedan        99.8   177.3         ohc             five
# 4      4    audi      sedan        99.4   176.6         ohc             five
# 6      6    audi      wagon       105.8   192.7         ohc             five
#
#    horsepower  average-mileage    price
# 3         102               24  13950.0
# 5         110               19  15250.0
# 4         115               18  17450.0
# 6         110               19  18920.0

# %%
# selecting the column body style.
df['body-style']
# Out:
# 0     convertible
# 1     convertible
# 2       hatchback
# 3           sedan
# 4           sedan
#          ...
# 56          sedan
# 57          sedan
# 58          sedan
# 59          sedan
# 60          wagon
# Name: body-style, Length: 61, dtype: object

# %%
# Counting the numbers of convertible

# num_convertible = df['body-style'].value_counts().get('convertible')
# num_convertible = df['body-style'].value_counts().get('sedan')
# num_convertible = df['body-style'].value_counts().get('hatchback')
num_convertible = df['body-style'].value_counts().get('wagon')
num_convertible
# Out:
# 9

# %%
df['body-style'].value_counts().head()
# Out:
# body-style
# sedan          32
# hatchback      15
# wagon           9
# convertible     3
# hardtop         2
# Name: count, dtype: int64

# %%
df['company'].value_counts().head(10)
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# Name: count, dtype: int64

# %%
df['price'].value_counts().head()
# Out:
# price
# 16500.0    2
# 34028.0    1
# 28248.0    1
# 40960.0    1
# 45400.0    1
# Name: count, dtype: int64

# %%
# Counting unique values
df_unique = df['body-style'].nunique()

# Checking the values of unique items in the body-style column 
df_uniques = df['body-style'].unique()


print (df_unique)
df_uniques
# Out:
# 5
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
# raw selection 
# 1. by their position 

df_psn = df [10:20]
# print (df_psn)
df_psn

# 2. by ther labels
df_lab = df_sub.loc[10:20, ['company', 'body-style', 'price']]
df_lab
# df_sub

df_lbl = df_sub.iloc[10:20, [1, 4, 5, 6]]
df_lbl
# Out:
#           company  length engine-type num-of-cylinders
# 12            bmw   197.0         ohc              six
# 24         jaguar   199.6        dohc              six
# 25         jaguar   199.6        dohc              six
# 26         jaguar   191.7        ohcv           twelve
# 31          mazda   175.0         ohc             four
# 32  mercedes-benz   190.9         ohc             five
# 33  mercedes-benz   190.9         ohc             five
# 34  mercedes-benz   208.1        ohcv            eight
# 35  mercedes-benz   199.2        ohcv            eight
# 45        porsche   168.9        ohcf              six

# %%
# Creating a new dasta frame from the original sorted by the column company 
df_sort = df.sort_values(by='company')

df_sort.head()

# Sorting the data using 2 or more column 
df_sort = df.sort_values(by=['company', 'price'], ascending= [True, False])
df_sort.head(10)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 6       6         audi        wagon       105.8   192.7         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# 5       5         audi        sedan        99.8   177.3         ohc
# 3       3         audi        sedan        99.8   176.6         ohc
# 11     14          bmw        sedan       103.5   193.8         ohc
# 12     15          bmw        sedan       110.0   197.0         ohc
# 10     13          bmw        sedan       103.5   189.0         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 1              four         111               21  16500.0
# 2               six         154               19  16500.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             61 non-null     int64
#  1   company           61 non-null     object
#  2   body-style        61 non-null     object
#  3   wheel-base        61 non-null     float64
#  4   length            61 non-null     float64
#  5   engine-type       61 non-null     object
#  6   num-of-cylinders  61 non-null     object
#  7   horsepower        61 non-null     int64
#  8   average-mileage   61 non-null     int64
#  9   price             58 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
# Using agg() methods to perfom multiple statistics 
df[['length','price']].agg(['min', 'mean', 'max'])
# Out:
#           length    price
# min   141.100000   5151.0
# mean  173.098361  15387.0
# max   208.100000  45400.0

# %%
# Checking the values of the column of the data 
df.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
# Checking teh sum of the null items in the data 
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
# Identifying and counting missing values in a data frame 
df.isnull().count()
# Out:
# index               61
# company             61
# body-style          61
# wheel-base          61
# length              61
# engine-type         61
# num-of-cylinders    61
# horsepower          61
# average-mileage     61
# price               61
# dtype: int64

# %%
df.dropna()
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# ...

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
# checking the price column and calcluating its mean 

price = df['price']
price.head()

# Getting the mean  of the price 
price_mean = price.mean()
price_mean
# Out:
# 15387.0

# %%
# Filling the missing values on the column price
# Filling it with the mean price 

price.fillna(price_mean, inplace=True)

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df.price,61
# Out:
# (0     13495.0
#  1     16500.0
#  2     16500.0
#  3     13950.0
#  4     17450.0
#         ...
#  56     7975.0
#  57     7995.0
#  58     9995.0
#  59    12940.0
#  60    13415.0
#  Name: price, Length: 61, dtype: float64,
#  61)

# %%
df['price'].describe()
# Out:
# count       61.00000
# mean     15387.00000
# std      11033.62446
# min       5151.00000
# 25%       6849.00000
# 50%      12940.00000
# 75%      17450.00000
# max      45400.00000
# Name: price, dtype: float64

# %%
df.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   61.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#              price
# count     61.00000
# mean   15387.00000
# std    11033.62446
# min     5151.00000
# 25%     6849.00000
# 50%    12940.00000
# 75%    17450.00000
# max    45400.00000

# %%
# Computing teh pairwise correlation of columns 
# df.corr()

# %%
df[df['company'] == 'bmw']
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 7       9     bmw      sedan       101.2   176.8         ohc             four
# 8      10     bmw      sedan       101.2   176.8         ohc             four
# 9      11     bmw      sedan       101.2   176.8         ohc              six
# 10     13     bmw      sedan       103.5   189.0         ohc              six
# 11     14     bmw      sedan       103.5   193.8         ohc              six
# 12     15     bmw      sedan       110.0   197.0         ohc              six
#
#     horsepower  average-mileage    price
# 7          101               23  16430.0
# 8          101               23  16925.0
# 9          121               21  20970.0
# 10         182               16  30760.0
# 11         182               16  41315.0
# 12         182               15  36880.0

# %%
df[df['price'] >= 25000]
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# 12     15            bmw        sedan       110.0   197.0         ohc
# 24     33         jaguar        sedan       113.0   199.6        dohc
# 25     34         jaguar        sedan       113.0   199.6        dohc
# 26     35         jaguar        sedan       102.0   191.7        ohcv
# 32     44  mercedes-benz        sedan       110.0   190.9         ohc
# 33     45  mercedes-benz        wagon       110.0   190.9         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 45     61        porsche      hardtop        89.5   168.9        ohcf
# 46     62        porsche  convertible        89.5   168.9        ohcf
#
# ...

# %%
# using matplotlib

# set the font an plot size
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

df.plot(kind='scatter', x ='average-mileage', y='price',title='Vehicle Revenue(Kshs)vs Mileage')
# Out:
# <Axes: title={'center': 'Vehicle Revenue(Kshs)vs Mileage'}, xlabel='average-mileage', ylabel='price'>

# %%
# using matplotlib

# set the font an plot size
plt.rcParams.update({'font.size': 10, 'figure.figsize': (10, 8)})

df.plot(kind='hexbin', x ='average-mileage', y='price',title='Vehicle Revenue(Kshs)vs Mileage')


# istogram is not a valid plot kind Valid plot kinds: 
# ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin
# Out:
# <Axes: title={'center': 'Vehicle Revenue(Kshs)vs Mileage'}, xlabel='average-mileage', ylabel='price'>

# %%
df['horsepower'].describe()
# Out:
# count     61.000000
# mean     107.852459
# std       53.524398
# min       48.000000
# 25%       68.000000
# 50%      100.000000
# 75%      123.000000
# max      288.000000
# Name: horsepower, dtype: float64

# %%
df['horsepower'].plot(kind='box')
# Out:
# <Axes: >
